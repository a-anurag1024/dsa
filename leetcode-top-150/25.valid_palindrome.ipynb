# %% [markdown]
# source: [LeetCode](https://leetcode.com/problems/valid-palindrome/description/?envType=study-plan-v2&envId=top-interview-150)

# %% [markdown]
# # 🔁 LeetCode 125 — Valid Palindrome (Easy)
#
# ---
#
# ## 🧩 Problem Summary
#
# Given a string `s`, determine if it is a **palindrome**, considering only **alphanumeric** characters and ignoring **cases**.
#
# A string is a palindrome if it reads the same forward and backward.
#
# - Ignore spaces, punctuation, and symbols.
# - Compare characters case-insensitively.
#
# ---
#
# ## 🧠 Examples
#
# ### Example 1:
# **Input:**
# `s = "A man, a plan, a canal: Panama"`
# **Output:** `true`
# **Explanation:**
# After cleaning → `"amanaplanacanalpanama"` → same forward and backward ✅
#
# ---
#
# ### Example 2:
# **Input:**
# `s = "race a car"`
# **Output:** `false`
# **Explanation:**
# After cleaning → `"raceacar"` → not a palindrome ❌
#
# ---
#
# ### Example 3:
# **Input:**
# `s = " "`
# **Output:** `true`
# **Explanation:**
# After cleaning → `""` (empty string) → trivially a palindrome ✅
#
# ---
#
# ## ⚙️ Approach (Two-Pointer Technique)
#
# ### 🔹 Key Idea:
# Use two pointers — one starting from the left, one from the right — and compare characters after:
# - Lowercasing
# - Skipping non-alphanumeric characters
#
# ---
#
# ### 🔹 Step-by-Step
#
# 1. Initialize two pointers: `l = 0`, `r = len(s) - 1`
# 2. While `l < r`:
#    - Move `l` forward until `s[l]` is alphanumeric.
#    - Move `r` backward until `s[r]` is alphanumeric.
#    - Compare `s[l].lower()` and `s[r].lower()`.
#    - If mismatch → return `False`
#    - Otherwise, move both inward.
# 3. If all characters match → return `True`
#
# ---
#
# ## 🧑‍💻 Python Sketch
#
# ```python
# def isPalindrome(s: str) -> bool:
#     l, r = 0, len(s) - 1
#     while l < r:
#         while l < r and not s[l].isalnum():
#             l += 1
#         while l < r and not s[r].isalnum():
#             r -= 1
#         if s[l].lower() != s[r].lower():
#             return False
#         l += 1
#         r -= 1
#     return True

# %% [markdown]
# # My solution

# %%
class Solution(object):
    def isPalindrome(self, s):
        """
        :type s: str
        :rtype: bool
        """
        st = 0
        en = len(s) - 1
        while st < en:
            if not s[st].isalnum():
                st += 1
                continue
            if not s[en].isalnum():
                en -= 1
                continue
            if s[st].lower() != s[en].lower(): return False
            st += 1
            en -= 1
        return True
