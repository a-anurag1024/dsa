# %% [markdown]
# source: [LeetCode](https://leetcode.com/problems/sum-root-to-leaf-numbers/?envType=study-plan-v2&envId=top-interview-150)

# %% [markdown]
# # 🔢 Quick Review — LeetCode 129: Sum Root to Leaf Numbers
# **Difficulty:** Medium
# **Topic:** Binary Trees / DFS / Recursion
#
# ---
#
# ## 📌 Problem Summary
# Given a binary tree where each node contains a **digit (0–9)**, each root-to-leaf path forms a number by concatenation.
#
# Goal:
# Compute the **sum of all root-to-leaf numbers**.
#
# For example:
# Path `1 → 2 → 3` represents **123**.
#
# ---
#
# ## 🔍 Examples
#
# ### Example 1
# **Input:** `[1,2,3]`
# Paths:
# - `1 → 2` → 12
# - `1 → 3` → 13
# **Output:** `12 + 13 = 25`
#
# ### Example 2
# **Input:** `[4,9,0,5,1]`
# Paths:
# - 4 → 9 → 5 → 495
# - 4 → 9 → 1 → 491
# - 4 → 0 → 40
# **Output:** `1026`
#
# ---
#
# ## 🚀 Key Idea
# Perform a depth-first traversal where the **current path number** is built as:
#
# new_number = old_number * 10 + node.val
#
#
# Whenever you reach a **leaf**, add the current number to the total sum.
#
# ---
#
# ## 📝 Short Approach (Interview-Ready)
#
# ### Recursive DFS:
# 1. Keep track of the *running number* as you traverse.
# 2. At each node:
#
# curr = acc * 10 + node.val
#
# 3. If node is a **leaf**, return curr.
# 4. Else return:
#
# dfs(node.left, curr) + dfs(node.right, curr)
#
#
# ### Iterative DFS / BFS also works, but recursion is simplest.
#
# Time Complexity: **O(n)**
# Space Complexity: **O(h)** recursion (h = tree height)
#
# ---
#
# ## 🧑‍💻 Template Code (Recursive DFS)
#
# ```python
# class Solution:
#  def sumNumbers(self, root):
#      def dfs(node, curr):
#          if not node:
#              return 0
#
#          curr = curr * 10 + node.val
#
#          if not node.left and not node.right:
#              return curr  # leaf reached
#
#          return dfs(node.left, curr) + dfs(node.right, curr)
#
#      return dfs(root, 0)

# %% [markdown]
# # My Solution

# %%
# Definition for a binary tree node.
class TreeNode(object):
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution(object):
    def sumNumbers(self, root):
        """
        :type root: Optional[TreeNode]
        :rtype: int
        """
        def helper(curr, curr_sum, total_sum):
            if not curr:
                total_sum += curr_sum
                return total_sum
            curr_sum = 10*curr_sum + curr.val
            if not curr.left and not curr.right:
                return helper(None, curr_sum, total_sum)
            if curr.left:
                total_sum = helper(curr.left, curr_sum, total_sum)
            if curr.right:
                total_sum = helper(curr.right, curr_sum, total_sum)
            return total_sum
        return helper(root, 0, 0)
