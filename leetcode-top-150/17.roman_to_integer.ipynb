# %% [markdown]
# source: [LeetCode](https://leetcode.com/problems/roman-to-integer/?envType=study-plan-v2&envId=top-interview-150)

# %% [markdown]
# # 🔢 LeetCode 13 — Roman to Integer (Easy)
#
# ---
#
# ## 🧩 Problem Summary
#
# Convert a Roman numeral string `s` into its corresponding **integer** value.
#
# Roman numerals are made up of **7 symbols**:
#
# | Symbol | Value |
# |:-------:|:------:|
# | I | 1 |
# | V | 5 |
# | X | 10 |
# | L | 50 |
# | C | 100 |
# | D | 500 |
# | M | 1000 |
#
# Normally, numerals are written **largest to smallest** from left to right.
# However, **subtractive notation** applies in certain cases.
#
# ---
#
# ## ⚙️ Subtractive Rules
#
# A smaller numeral **before** a larger one means **subtraction**:
#
# | Combination | Value | Explanation |
# |:-------------|:------:|:------------|
# | IV | 4 | 5 − 1 |
# | IX | 9 | 10 − 1 |
# | XL | 40 | 50 − 10 |
# | XC | 90 | 100 − 10 |
# | CD | 400 | 500 − 100 |
# | CM | 900 | 1000 − 100 |
#
# ---
#
# ## 🧠 Example
#
# | Input | Output | Explanation |
# |:------|:--------|:-------------|
# | `"III"` | `3` | 1 + 1 + 1 |
# | `"LVIII"` | `58` | 50 + 5 + 3 |
# | `"MCMXCIV"` | `1994` | 1000 + 900 + 90 + 4 |
#
# ---
#
# ## ⚙️ Approach (Greedy Scan from Left to Right)
#
# ### 🔹 Idea:
# - Traverse the string once.
# - For each symbol:
#   - If **its value is less than the next symbol**, **subtract** it.
#   - Else, **add** it.
#
# This handles all subtraction cases automatically.
#
# ---
#
# ### 🧮 Step-by-Step (Example: `"MCMXCIV"`)
#
# | Index | Symbol | Value | Next | Action | Result |
# |:------|:--------|:------|:-----|:-------|:--------|
# | 0 | M | 1000 | C | Add | 1000 |
# | 1 | C | 100 | M | Subtract | 900 |
# | 2 | M | 1000 | X | Add | 1900 |
# | 3 | X | 10 | C | Subtract | 1890 |
# | 4 | C | 100 | I | Add | 1990 |
# | 5 | I | 1 | V | Subtract | 1994 |
# | ✅ | Total | | | | **1994** |
#
# ---
#
# ## 🧑‍💻 Python Sketch
#
# ```python
# def romanToInt(s: str) -> int:
#     roman_map = {
#         'I': 1, 'V': 5, 'X': 10,
#         'L': 50, 'C': 100,
#         'D': 500, 'M': 1000
#     }
#
#     total = 0
#     for i in range(len(s)):
#         # If the next value is greater, subtract current value
#         if i + 1 < len(s) and roman_map[s[i]] < roman_map[s[i + 1]]:
#             total -= roman_map[s[i]]
#         else:
#             total += roman_map[s[i]]
#     return total

# %%
# My solution 
class Solution(object):
    def romanToInt(self, s):
        roman = {'I':1, 'V':5, 'X':10, 'L':50, 'C':100, 'D':500, 'M':1000}
        val = 0
        for i in range(len(s)):
            if i+1 < len(s) and roman[s[i]] < roman[s[i+1]]:
                val -= roman[s[i]]
            else:
                val += roman[s[i]]
        return val
